# %%
#!pip install pandas

# %%
from xgboost import XGBClassifier
from xgboost import plot_tree
import xgboost as xgb
# read data
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import pandas

# %%
data = load_iris()
X_train, X_test, y_train, y_test = train_test_split(
    data['data'], data['target'], test_size=.2)

# %%
# create model instance
bst = XGBClassifier(n_estimators=10, max_depth=10,
                    learning_rate=1, objective='binary:logistic')
# fit model
bst.fit(X_train, y_train)
# make predictions
preds = bst.predict(X_test)

# %%
boost = bst.get_booster()

# %%
trees = boost.get_dump(with_stats=True)

# %%
print(trees[0])
# Out:
# 0:[f2<2.45000005] yes=1,no=2,missing=1,gain=57.3227081,cover=53.3333282
# 	1:leaf=1.42011833,cover=17.7777767
# 	2:leaf=-0.729483366,cover=35.5555534

# %%
xpar = bst.get_xgb_params()
par = bst.get_params()

# %%
boost.trees_to_dataframe()
# Out:
#     Tree  Node   ID Feature  Split  Yes   No Missing       Gain      Cover  \
# 0      0     0  0-0      f2   2.45  0-1  0-2     0-1  57.322708  53.333328
# 1      0     1  0-1    Leaf    NaN  NaN  NaN     NaN   1.420118  17.777777
# 2      0     2  0-2    Leaf    NaN  NaN  NaN     NaN  -0.729483  35.555553
# 3      1     0  1-0      f2   2.45  1-1  1-2     1-1  12.222784  53.333328
# 4      1     1  1-1    Leaf    NaN  NaN  NaN     NaN  -0.710059  17.777777
# 5      1     2  1-2      f3   1.75  1-3  1-4     1-3  30.881550  35.555553
# 6      1     3  1-3    Leaf    NaN  NaN  NaN     NaN   1.161850  18.222221
# 7      1     4  1-4    Leaf    NaN  NaN  NaN     NaN  -0.654545  17.333332
# 8      2     0  2-0      f2   4.75  2-1  2-2     2-1  47.793629  53.333328
# 9      2     1  2-1      f3   1.45  2-3  2-4     2-3   0.109407  32.444443
# 10     2     2  2-2      f3   1.75  2-5  2-6     2-5   2.800951  20.888887
# 11     2     3  2-3    Leaf    NaN  NaN  NaN     NaN  -0.725275  29.333332
# 12     2     4  2-4    Leaf    NaN  NaN  NaN     NaN  -0.324324   3.111111
# 13     2     5  2-5    Leaf    NaN  NaN  NaN     NaN   0.292683   3.555555
# 14     2     6  2-6    Leaf    NaN  NaN  NaN     NaN   1.363636  17.333332
# 15     3     0  3-0      f2   2.45  3-1  3-2     3-1   8.732266  27.339222
# 16     3     1  3-1    Leaf    NaN  NaN  NaN     NaN   0.571644  12.353239
# 17     3     2  3-2    Leaf    NaN  NaN  NaN     NaN  -0.523929  14.985983
# 18     4     0  4-0      f2   4.95  4-1  4-2     4-1   3.576102  30.084927
# 19     4     1  4-1      f2   2.45  4-3  4-4     4-3   5.342817  21.066090
# 20     4     2  4-2      f3   1.55  4-5  4-6     4-5   0.052801   9.018838
# 21     4     3  4-3    Leaf    NaN  NaN  NaN     NaN  -0.483618   6.951911
# 22     4     4  4-4    Leaf    NaN  NaN  NaN     NaN   0.532274  14.114179
# 23     4     5  4-5    Leaf    NaN  NaN  NaN     NaN  -0.800228   1.387594
# 24     4     6  4-6    Leaf    NaN  NaN  NaN     NaN  -0.394125   7.631244
# 25     5     0  5-0      f2   4.85  5-1  5-2     5-1   9.222932  29.920775
# 26     5     1  5-1      f3   1.65  5-3  5-4     5-3   0.837805  15.491136
# 27     5     2  5-2      f2   4.95  5-5  5-6     5-5   0.158919  14.429639
# 28     5     3  5-3    Leaf    NaN  NaN  NaN     NaN  -0.529113  14.242429
# 29     5     4  5-4    Leaf    NaN  NaN  NaN     NaN   0.199029   1.248707
# 30     5     5  5-5    Leaf    NaN  NaN  NaN     NaN   0.145758   1.365578
# 31     5     6  5-6    Leaf    NaN  NaN  NaN     NaN   0.649032  13.064060
#
#     Category
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# 31       NaN

# %%
for i in range(6):
    xgb.plot_tree(bst, num_trees=i)

# %%
for i in trees:
    print(i)
# Out:
# 0:[f2<2.45000005] yes=1,no=2,missing=1
# 	1:leaf=1.42011833
# 	2:leaf=-0.729483366
#
# 0:[f2<2.45000005] yes=1,no=2,missing=1
# 	1:leaf=-0.710059226
# 	2:[f3<1.75] yes=3,no=4,missing=3
# 		3:leaf=1.16184974
# 		4:leaf=-0.654545486
#
# 0:[f2<4.75] yes=1,no=2,missing=1
# 	1:[f3<1.45000005] yes=3,no=4,missing=3
# 		3:leaf=-0.725274801
# 		4:leaf=-0.324324369
# 	2:[f3<1.75] yes=5,no=6,missing=5
# 		5:leaf=0.292682886
# 		6:leaf=1.36363637
#
# 0:[f2<2.45000005] yes=1,no=2,missing=1
# 	1:leaf=0.571644247
# 	2:leaf=-0.523928642
#
# 0:[f2<4.94999981] yes=1,no=2,missing=1
# 	1:[f2<2.45000005] yes=3,no=4,missing=3
# 		3:leaf=-0.48361811
# 		4:leaf=0.532274008
# 	2:[f3<1.54999995] yes=5,no=6,missing=5
# 		5:leaf=-0.80022788
# 		6:leaf=-0.394124508
#
# 0:[f2<4.85000038] yes=1,no=2,missing=1
# 	1:[f3<1.6500001] yes=3,no=4,missing=3
# 		3:leaf=-0.529112995
# 		4:leaf=0.199029401
# 	2:[f2<4.94999981] yes=5,no=6,missing=5
# 		5:leaf=0.14575775
# 		6:leaf=0.649031818

# %%
trees = bst.get_booster().get_dump()
print(trees[0])
# Out:
# 0:[f2<2.45000005] yes=1,no=2,missing=1
# 	1:leaf=1.42011833
# 	2:leaf=-0.729483366

# %%
model2 = xgb.XGBClassifier()
model2.load_model("bst.json")
xgb.plot_tree(model2, num_trees=1)
# Out:
# <Axes: >

# %%
model2.predict(X_test)
# Out:
# array([0, 2, 0, 0, 0, 1, 1, 1, 1, 0, 1, 2, 1, 0, 2, 0, 2, 2, 2, 1, 0, 1,
#        2, 1, 0, 2, 2, 1, 0, 2], dtype=int64)

# %%
xgb.plot_tree(bst, num_trees=1
             )
# Out:
# <Axes: >

# %%
trees2 = model2.get_booster().get_dump()
print(trees2[0])
# Out:
# 0:[f2<2.45000005] yes=1,no=2,missing=1
# 	1:leaf=1.41818178
# 	2:leaf=-0.729729772

# %%
preds = model2.predict(X_test)

# %%
import pprint

# %%
print(trees[0])
# Out:
# 0:[f2<2.45000005] yes=1,no=2,missing=1
# 	1:leaf=1.42011833
# 	2:leaf=-0.729483366

# %%
# Use "gpu_hist" for training the model.
#reg = xgb.XGBRegressor(tree_method="gpu_hist")
# Fit the model using predictor X and response y.
#reg.fit(X, y)
# Save model into JSON format.
bst.save_model("bst.json")
